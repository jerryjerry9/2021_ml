# %%
###data processing assoicated package
import pickle
import pprint
import gc 
import datetime
import numpy as np
###drawing package
import os
os.environ['PROJ_LIB'] = 'C:\\Users\\jerry\\anaconda3\\Library\\share\\'
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib as mpl
from mpl_toolkits.basemap import Basemap
import glob
import netCDF4 as nc
import pickle
import csv
import numpy.ma as ma

# %%
with open('topo_regrid_2km.pkl', 'rb') as f:
    topo = pickle.load(f)

# %%
s20200208=open('47918.20200208_00.csv')
csvreader = csv.reader(s20200208)
header = []
header = next(csvreader)
header
rows = []
for row in csvreader:
        rows.append(row)
s0208=np.zeros((20,3))
for i in range(0,20):
 data=rows[i]
 print(data[2],data[3],data[5])
 s0208[i,0]=float(data[2])
 s0208[i,1]=float(data[3])
 s0208[i,2]=float(data[5])
# Out:
# 7.0 18.0 60.0
# 24.0 17.0 48.0
# 202.0 16.0 59.0
# 858.0 10.0 80.0
# 1047.0 8.5 85.0
# 1555.0 4.6 99.0
# 1661.0 4.4 99.0
# 1671.0 4.4 99.0
# 1848.0 8.2 61.0
# 1929.0 11.0 54.0
# 2001.0 10.5 53.0
# 2660.0 5.6 45.0
# 3142.0 0.8 59.0
# 3315.0 -0.8 63.0
# 3374.0 -1.3 64.0
# 3721.0 0.0 17.0
# 3746.0 1.2 11.0
# 3883.0 1.0 9.0
# 4244.0 2.0 4.0
# 4322.0 1.6 4.0

# %%
h20200208=open('2020020800.csv')
csvreader = csv.reader(h20200208)
header = []
header = next(csvreader)
header
rows = []
for row in csvreader:
        rows.append(row)
h0208=np.zeros((20,3))
for i in range(0,20):
 data=rows[i]
 print(data[3],data[4],data[8])
 h0208[i,0]=float(data[3])
 h0208[i,1]=float(data[4])
 h0208[i,2]=float(data[8])
# Out:
# 19.0 18.8 69.0
# 202.0 16.9 70.0
# 212.0 16.8 70.0
# 739.0 12.2 89.0
# 861.0 11.0 95.0
# 984.0 9.9 100.0
# 1450.0 7.9 100.0
# 1561.0 7.4 100.0
# 2064.0 4.7 100.0
# 2138.0 4.2 100.0
# 2189.0 6.5 78.0
# 2279.0 7.1 69.0
# 2452.0 6.7 62.0
# 2676.0 4.8 66.0
# 2690.0 4.7 66.0
# 3150.0 1.0 64.0
# 3244.0 0.1 64.0
# 3359.0 -0.6 64.0
# 3390.0 -0.4 62.0
# 3539.0 2.2 23.0

# %%
s20200306=open('47918.20200306_00.csv')
csvreader = csv.reader(s20200306)
header = []
header = next(csvreader)
header
rows = []
for row in csvreader:
        rows.append(row)
s0306=np.zeros((20,3))
for i in range(0,20):
 data=rows[i]
 print(data[2],data[3],data[5])
 s0306[i,0]=float(data[2])
 s0306[i,1]=float(data[3])
 s0306[i,2]=float(data[5])
# Out:
# 7.0 18.6 79.0
# 24.0 18.2 64.0
# 168.0 17.8 68.0
# 322.0 16.5 72.0
# 827.0 12.4 88.0
# 991.0 11.3 90.0
# 1168.0 10.2 93.0
# 1309.0 9.8 93.0
# 1531.0 9.2 94.0
# 1639.0 8.8 94.0
# 1922.0 7.8 92.0
# 2004.0 7.6 78.0
# 2150.0 9.2 76.0
# 2624.0 6.7 64.0
# 2951.0 5.0 56.0
# 3138.0 4.0 52.0
# 4220.0 -1.0 22.0
# 4233.0 -1.1 22.0
# 5483.0 -9.7 28.0
# 5800.0 -11.1 17.0

# %%
h20200306=open('2020030600.csv')
csvreader = csv.reader(h20200306)
header = []
header = next(csvreader)
header
rows = []
for row in csvreader:
        rows.append(row)
h0306=np.zeros((20,3))
for i in range(0,20):
 data=rows[i]
 print(data[3],data[4],data[8])
 h0306[i,0]=float(data[3])
 h0306[i,1]=float(data[4])
 h0306[i,2]=float(data[8])
# Out:
# 19.0 17.4 87.0
# 170.0 16.1 85.0
# 825.0 13.3 78.0
# 831.0 13.3 78.0
# 1209.0 10.6 100.0
# 1538.0 9.2 91.0
# 1659.0 8.3 93.0
# 1857.0 6.6 100.0
# 2037.0 5.7 99.0
# 2062.0 8.3 81.0
# 2102.0 8.9 76.0
# 2283.0 8.5 73.0
# 2730.0 6.3 69.0
# 3048.0 4.0 73.0
# 3137.0 3.5 72.0
# 3294.0 2.6 70.0
# 3484.0 3.4 45.0
# 3687.0 2.5 43.0
# 3734.0 3.1 19.0
# 3821.0 2.9 13.0

# %%
print(s0208[s0208[:,2]>90,:])
# Out:
# [[1555.     4.6   99. ]
#  [1661.     4.4   99. ]
#  [1671.     4.4   99. ]]

# %%
print(h0208[h0208[:,2]>90,:])
# Out:
# [[ 861.    11.    95. ]
#  [ 984.     9.9  100. ]
#  [1450.     7.9  100. ]
#  [1561.     7.4  100. ]
#  [2064.     4.7  100. ]
#  [2138.     4.2  100. ]]

# %%
print(s0306[s0306[:,2]>90,:])
# Out:
# [[1168.    10.2   93. ]
#  [1309.     9.8   93. ]
#  [1531.     9.2   94. ]
#  [1639.     8.8   94. ]
#  [1922.     7.8   92. ]]

# %%
print(h0306[h0306[:,2]>90,:])
# Out:
# [[1209.    10.6  100. ]
#  [1538.     9.2   91. ]
#  [1659.     8.3   93. ]
#  [1857.     6.6  100. ]
#  [2037.     5.7   99. ]]

# %%
with open('test_band13_202002080000.pkl', 'rb') as f:
    band13= pickle.load(f)

# %%
with open('test_band13_202003060000.pkl', 'rb') as f:
    band13_0306= pickle.load(f)

# %%
x = np.arange(85.01,205.01,0.02)
y = np.arange(-59.99,60.01,0.02)
local_lon=x[1700:1901]
local_lat=y[4050:4300]
print(local_lon.shape)
# Out:
# (201,)

# %%
fig = plt.figure(figsize=(8,8)) 
m = Basemap(llcrnrlon=118.5, urcrnrlon=123.5, llcrnrlat=21, urcrnrlat=26,resolution='l')
m.drawcoastlines(linewidth=1.1,color='limegreen')
m.drawparallels(np.arange(22., 27., 2.), labels=[1, 0, 0, 0], linewidth=1.5, color='k', fontsize=18)
m.drawmeridians(np.arange(118., 123., 2.), labels=[0, 0, 0, 1], linewidth=1.5, color='k', fontsize=18)

cmap2 = cm.get_cmap("terrain",lut=19)
cmap2.set_under("w")
cmap2.set_over("k")

m.pcolormesh(local_lon,local_lat,topo,cmap=cmap2,vmin=0,vmax=3800)#,cmap=cmap2,vmin=200,vmax=300)
plt.tight_layout()

# %%
print(band13.shape)
hi_lon=x[1675:2175]
hi_lat=y[4050:4300]
tw_band13=band13[:,25:226]
tw_band13_0306=band13_0306[:,25:226]
# Out:
# (250, 500)

# %%
fig = plt.figure(figsize=(16,8)) 
m = Basemap(llcrnrlon=118.5, urcrnrlon=128.5, llcrnrlat=21, urcrnrlat=26,resolution='l')
m.drawcoastlines(linewidth=1.5,color='limegreen')
m.drawparallels(np.arange(22., 27., 2.), labels=[1, 0, 0, 0], linewidth=1.5, color='k', fontsize=18)
m.drawmeridians(np.arange(118., 123., 2.), labels=[0, 0, 0, 1], linewidth=1.5, color='k', fontsize=18)

cmap2 = cm.get_cmap("gray_r",lut=22)
cmap2.set_under("white")
cmap2.set_over("k")
out1=ma.masked_where(band13>295, band13)
out=ma.masked_where(out1<250, out1)
m.pcolormesh(hi_lon,hi_lat,out,cmap=cmap2,vmin=270,vmax=292)
plt.scatter(124.2,24.4,s=80,c='tab:red',marker='o',zorder=2.5)
plt.tight_layout()

# %%
fig = plt.figure(figsize=(16,8)) 
m = Basemap(llcrnrlon=118.5, urcrnrlon=128.5, llcrnrlat=21, urcrnrlat=26,resolution='l')
m.drawcoastlines(linewidth=1.5,color='limegreen')
m.drawparallels(np.arange(22., 27., 2.), labels=[1, 0, 0, 0], linewidth=1.5, color='k', fontsize=18)
m.drawmeridians(np.arange(118., 123., 2.), labels=[0, 0, 0, 1], linewidth=1.5, color='k', fontsize=18)

cmap2 = cm.get_cmap("gray_r",lut=22)
cmap2.set_under("white")
cmap2.set_over("k")
out1=ma.masked_where(band13>280, band13)
out=ma.masked_where(out1<275, out1)
m.pcolormesh(hi_lon,hi_lat,out,cmap=cmap2,vmin=270,vmax=292)
plt.scatter(124.2,24.4,s=80,c='tab:red',marker='o',zorder=2.5)

out_t1=ma.masked_where(topo<1800, topo)
m.pcolormesh(local_lon,local_lat,out_t1,cmap=cmap,vmin=1200,vmax=4000,alpha=0.3)
plt.tight_layout()

# %%
out1=ma.masked_where(tw_band13>280, tw_band13)
out2=ma.masked_where(out1<275, out1)
out=ma.masked_where(topo<=1900, topo)
heigth=1800
print(out.shape)
cloud_mask=np.zeros((250,201))
for i in range(1,249):
    for j in range(1,200):
        if out[i+1,j]>0 and topo[i,j]<heigth and tw_band13[i,j]<=280 and  tw_band13[i,j]>=275:
            cloud_mask[i,j]=1
        if out[i-1,j]>0 and topo[i,j]<heigth and tw_band13[i,j]<=280 and  tw_band13[i,j]>=275:
            cloud_mask[i,j]=1
        if out[i,j+1]>0 and topo[i,j]<heigth and tw_band13[i,j]<=280 and  tw_band13[i,j]>=275:
            cloud_mask[i,j]=1
        if out[i,j-1]>0 and topo[i,j]<heigth and tw_band13[i,j]<=280 and  tw_band13[i,j]>=275:
            cloud_mask[i,j]=1

        if out[i+1,j+1]>0 and topo[i,j]<heigth and tw_band13[i,j]<=280 and  tw_band13[i,j]>=275:
            cloud_mask[i,j]=1
        if out[i+1,j-1]>0 and topo[i,j]<heigth and tw_band13[i,j]<=280 and  tw_band13[i,j]>=275:
            cloud_mask[i,j]=1
        if out[i-1,j+1]>0 and topo[i,j]<heigth and tw_band13[i,j]<=280 and  tw_band13[i,j]>=275:
            cloud_mask[i,j]=1
        if out[i-1,j-1]>0 and topo[i,j]<heigth and tw_band13[i,j]<=280 and  tw_band13[i,j]>=275:
            cloud_mask[i,j]=1
# Out:
# (250, 201)

# %%
fig = plt.figure(figsize=(16,8)) 
m = Basemap(llcrnrlon=118.5, urcrnrlon=123.5, llcrnrlat=21, urcrnrlat=26,resolution='l')
m.drawcoastlines(linewidth=1.5,color='limegreen')
m.drawparallels(np.arange(22., 27., 2.), labels=[1, 0, 0, 0], linewidth=1.5, color='k', fontsize=18)
m.drawmeridians(np.arange(118., 123., 2.), labels=[0, 0, 0, 1], linewidth=1.5, color='k', fontsize=18)

cmap2 = cm.get_cmap("gray_r",lut=22)
cmap2.set_under("white")
cmap2.set_over("k")
out1=ma.masked_where(band13>280, band13)
out=ma.masked_where(out1<275, out1)
m.pcolormesh(hi_lon,hi_lat,out,cmap=cmap2,vmin=270,vmax=292)

out=ma.masked_where(cloud_mask<0.5, cloud_mask)
m.pcolormesh(local_lon,local_lat,out)
plt.tight_layout()

# %%
fig = plt.figure(figsize=(16,8)) 
m = Basemap(llcrnrlon=118.5, urcrnrlon=128.5, llcrnrlat=21, urcrnrlat=26,resolution='l')
m.drawcoastlines(linewidth=1.5,color='limegreen')
m.drawparallels(np.arange(22., 27., 2.), labels=[1, 0, 0, 0], linewidth=1.5, color='k', fontsize=18)
m.drawmeridians(np.arange(118., 123., 2.), labels=[0, 0, 0, 1], linewidth=1.5, color='k', fontsize=18)

cmap2 = cm.get_cmap("gray_r",lut=42)
cmap2.set_under("white")
cmap2.set_over("k")
out1=ma.masked_where(band13_0306>295, band13_0306)
out=ma.masked_where(out1<250, out1)
m.pcolormesh(hi_lon,hi_lat,out,cmap=cmap2,vmin=250,vmax=292)
plt.scatter(124.2,24.4,s=80,c='tab:red',marker='o',zorder=2.5)
plt.tight_layout()

# %%
fig = plt.figure(figsize=(16,8)) 
m = Basemap(llcrnrlon=118.5, urcrnrlon=128.5, llcrnrlat=21, urcrnrlat=26,resolution='l')
m.drawcoastlines(linewidth=1.5,color='limegreen')
m.drawparallels(np.arange(22., 27., 2.), labels=[1, 0, 0, 0], linewidth=1.5, color='k', fontsize=18)
m.drawmeridians(np.arange(118., 123., 2.), labels=[0, 0, 0, 1], linewidth=1.5, color='k', fontsize=18)

cmap2 = cm.get_cmap("gray_r",lut=22)
cmap2.set_under("white")
cmap2.set_over("k")
out1=ma.masked_where(band13_0306>280, band13_0306)
out=ma.masked_where(out1<275, out1)
m.pcolormesh(hi_lon,hi_lat,out,cmap=cmap2,vmin=270,vmax=292)
plt.scatter(124.2,24.4,s=80,c='tab:red',marker='o',zorder=2.5)

out_t1=ma.masked_where(topo<1900, topo)
m.pcolormesh(local_lon,local_lat,out_t1,cmap=cmap,vmin=1200,vmax=4000,alpha=0.3)
plt.tight_layout()

# %%
out1=ma.masked_where(tw_band13_0306>284, tw_band13_0306)
out2=ma.masked_where(out1<277, out1)
out=ma.masked_where(topo<=1900, topo)
heigth=1900
hi_bt=280
lo_bt=275
print(out.shape)
cloud_mask=np.zeros((250,201))
for i in range(1,249):
    for j in range(1,200):
        if out[i+1,j]>0 and topo[i,j]<heigth and tw_band13_0306[i,j]<=hi_bt and  tw_band13_0306[i,j]>=lo_bt:
            cloud_mask[i,j]=1
        if out[i-1,j]>0 and topo[i,j]<heigth and tw_band13_0306[i,j]<=hi_bt and tw_band13_0306[i,j]>=lo_bt:
            cloud_mask[i,j]=1
        if out[i,j+1]>0 and topo[i,j]<heigth and tw_band13_0306[i,j]<=hi_bt and  tw_band13_0306[i,j]>=lo_bt:
            cloud_mask[i,j]=1
        if out[i,j-1]>0 and topo[i,j]<heigth and tw_band13_0306[i,j]<=hi_bt and  tw_band13_0306[i,j]>=lo_bt:
            cloud_mask[i,j]=1

        if out[i+1,j+1]>0 and topo[i,j]<heigth and tw_band13_0306[i,j]<=hi_bt and  tw_band13_0306[i,j]>=lo_bt:
            cloud_mask[i,j]=1
        if out[i+1,j-1]>0 and topo[i,j]<heigth and tw_band13_0306[i,j]<=hi_bt and  tw_band13_0306[i,j]>=lo_bt:
            cloud_mask[i,j]=1
        if out[i-1,j+1]>0 and topo[i,j]<heigth and tw_band13_0306[i,j]<=hi_bt and  tw_band13_0306[i,j]>=lo_bt:
            cloud_mask[i,j]=1
        if out[i-1,j-1]>0 and topo[i,j]<heigth and tw_band13_0306[i,j]<=hi_bt and  tw_band13_0306[i,j]>=lo_bt:
            cloud_mask[i,j]=1
# Out:
# (250, 201)

# %%
fig = plt.figure(figsize=(16,8)) 
m = Basemap(llcrnrlon=118.5, urcrnrlon=123.5, llcrnrlat=21, urcrnrlat=26,resolution='l')
m.drawcoastlines(linewidth=1.5,color='limegreen')
m.drawparallels(np.arange(22., 27., 2.), labels=[1, 0, 0, 0], linewidth=1.5, color='k', fontsize=18)
m.drawmeridians(np.arange(118., 123., 2.), labels=[0, 0, 0, 1], linewidth=1.5, color='k', fontsize=18)

cmap2 = cm.get_cmap("gray_r",lut=22)
cmap2.set_under("white")
cmap2.set_over("k")
out1=ma.masked_where(band13_0306>280, band13_0306)
out=ma.masked_where(out1<275, out1)
m.pcolormesh(hi_lon,hi_lat,out,cmap=cmap2,vmin=270,vmax=292)

out=ma.masked_where(cloud_mask<0.5, cloud_mask)
m.pcolormesh(local_lon,local_lat,out)
plt.tight_layout()

# %%
fig = plt.figure(figsize=(16,8)) 
m = Basemap(llcrnrlon=118.5, urcrnrlon=128.5, llcrnrlat=21, urcrnrlat=26,resolution='l')
m.drawcoastlines(linewidth=1.5,color='limegreen')
m.drawparallels(np.arange(22., 27., 2.), labels=[1, 0, 0, 0], linewidth=1.5, color='k', fontsize=18)
m.drawmeridians(np.arange(118., 123., 2.), labels=[0, 0, 0, 1], linewidth=1.5, color='k', fontsize=18)

cmap2 = cm.get_cmap("gray_r",lut=22)
cmap2.set_under("white")
cmap2.set_over("k")
out1=ma.masked_where(band13_0306>284, band13_0306)
out=ma.masked_where(out1<279, out1)
m.pcolormesh(hi_lon,hi_lat,out,cmap=cmap2,vmin=270,vmax=292)
plt.scatter(124.2,24.4,s=80,c='tab:red',marker='o',zorder=2.5)

out_t1=ma.masked_where(topo<1200, topo)
m.pcolormesh(local_lon,local_lat,out_t1,cmap=cmap,vmin=1200,vmax=4000,alpha=0.3)
plt.tight_layout()

# %%
out1=ma.masked_where(tw_band13_0306>284, tw_band13_0306)
out2=ma.masked_where(out1<279, out1)
out=ma.masked_where(topo<=1200, topo)
heigth=1200
hi_bt=284
lo_bt=279
print(out.shape)
cloud_mask=np.zeros((250,201))
for i in range(1,249):
    for j in range(1,200):
        if out[i+1,j]>0 and topo[i,j]<heigth and tw_band13_0306[i,j]<=hi_bt and  tw_band13_0306[i,j]>=lo_bt:
            cloud_mask[i,j]=1
        if out[i-1,j]>0 and topo[i,j]<heigth and tw_band13_0306[i,j]<=hi_bt and tw_band13_0306[i,j]>=lo_bt:
            cloud_mask[i,j]=1
        if out[i,j+1]>0 and topo[i,j]<heigth and tw_band13_0306[i,j]<=hi_bt and  tw_band13_0306[i,j]>=lo_bt:
            cloud_mask[i,j]=1
        if out[i,j-1]>0 and topo[i,j]<heigth and tw_band13_0306[i,j]<=hi_bt and  tw_band13_0306[i,j]>=lo_bt:
            cloud_mask[i,j]=1

        if out[i+1,j+1]>0 and topo[i,j]<heigth and tw_band13_0306[i,j]<=hi_bt and  tw_band13_0306[i,j]>=lo_bt:
            cloud_mask[i,j]=1
        if out[i+1,j-1]>0 and topo[i,j]<heigth and tw_band13_0306[i,j]<=hi_bt and  tw_band13_0306[i,j]>=lo_bt:
            cloud_mask[i,j]=1
        if out[i-1,j+1]>0 and topo[i,j]<heigth and tw_band13_0306[i,j]<=hi_bt and  tw_band13_0306[i,j]>=lo_bt:
            cloud_mask[i,j]=1
        if out[i-1,j-1]>0 and topo[i,j]<heigth and tw_band13_0306[i,j]<=hi_bt and  tw_band13_0306[i,j]>=lo_bt:
            cloud_mask[i,j]=1
# Out:
# (250, 201)

# %%
fig = plt.figure(figsize=(16,8)) 
m = Basemap(llcrnrlon=118.5, urcrnrlon=123.5, llcrnrlat=21, urcrnrlat=26,resolution='l')
m.drawcoastlines(linewidth=1.5,color='limegreen')
m.drawparallels(np.arange(22., 27., 2.), labels=[1, 0, 0, 0], linewidth=1.5, color='k', fontsize=18)
m.drawmeridians(np.arange(118., 123., 2.), labels=[0, 0, 0, 1], linewidth=1.5, color='k', fontsize=18)

cmap2 = cm.get_cmap("gray_r",lut=22)
cmap2.set_under("white")
cmap2.set_over("k")
out1=ma.masked_where(band13_0306>284, band13_0306)
out=ma.masked_where(out1<279, out1)
m.pcolormesh(hi_lon,hi_lat,out,cmap=cmap2,vmin=270,vmax=292)

out=ma.masked_where(cloud_mask<0.5, cloud_mask)
m.pcolormesh(local_lon,local_lat,out)
plt.tight_layout()
